# %% [markdown]
# This self-assesment notebook will check whether you watched and understood the videos on a practical example, I have shown in the videos.

# %% [markdown]
# # Senario:
#
# Our scenario is the one shown in the following ER diagram sbout architect and buildings:
#
# ![image.png](attachment:d0a9d9d9-d748-4fe6-9036-3a65858b58d5.png)

# %% [markdown]
# # Task 0:
#
# First, we load SQL magic functions and connect to the database server as shown in the FirstSteps.ipynb notebook, i.e. just execute the following cell:

# %%
import os
# %load_ext sql

    
LOGIN = os.environ.get('JUPYTERHUB_USER')
DATABASE = LOGIN
HOSTNAME = "postgresql.student-db.svc.cluster.local"

print("Login is recognized as ", LOGIN,". It should be your WU login.",)
print("If not, please change the previous line to be: LOGIN = 'hXYZYZY' # (replace hXYZYZY with your WU login)")


# %sql postgresql://$LOGIN:$LOGIN@$HOSTNAME/$DATABASE
# Out:
# /opt/conda/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /opt/conda/lib/python3.10/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# Login is recognized as  h11912099 . It should be your WU login.
# If not, please change the previous line to be: LOGIN = 'hXYZYZY' # (replace hXYZYZY with your WU login)

# %% [markdown]
# # Task 1:
#
# Next, in the following cell enter CREATE TABLE statements to create a database that corresponds to the ER diagram, from what you have seen in the videos about how to create a schema from a database.
# * make sure that each table has a PRIMARY KEY and that you add FOREIGN KEYs as required by the ER diagram
# * make sure to use proper datatypes for each attribute, that is:
#  * use INTEGER for numeric attributes
#  * use DATE for dates
#  * use VARCHAR for textual columns
# use table names `architect`, `building`, `person` as in the ER diagram.

# %%
# %%sql
#
# ... your SQL code here
# Out:
#  * postgresql://h11912099:***@postgresql.student-db.svc.cluster.local/h11912099
# (psycopg2.errors.SyntaxError) syntax error at or near ".."
# LINE 1: ... your SQL code here
#         ^
#
# [SQL: ... your SQL code here]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# # Task 2:
#
# Now
#
# a) add some INSERT INTO statements that contain the following information about buildings and persons:
#
# ![image.png](attachment:acb61d6a-6c63-4625-9910-e7e85cd6684f.png)
#
# b) How do you need to modify your database to also reflect the following information?
#  * The architect of the "Library and Learning center" is "Zaha Hadid"
#  * The architect of the "Departments 2 and Student Center" building is "Hitoshi Abe"
#  Also add the respective INSERT INTO or UPDATE statements.

# %%
# %%sql
#
# ... your SQL code here
# Out:
#  * postgresql://h11912099:***@postgresql.student-db.svc.cluster.local/h11912099
# (psycopg2.errors.SyntaxError) syntax error at or near ".."
# LINE 1: ... your SQL code here
#         ^
#
# [SQL: ... your SQL code here]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# # Task 3:
#
# Next, try to formulate some questions as SQL queries. We will start with some simple examples and then get more complex gradually...

# %% [markdown]
# ## Task 3.1
#
# Names of buildings that have been built before 2014 (Hint, you could use the function `EXTRACT(YEAR FROM inception_date)` from [PostgreSQL](https://www.postgresql.org/docs/current/functions-datetime.html) here.

# %%
# %%sql
#
# ...
# Out:
#  * postgresql://h11912099:***@postgresql.student-db.svc.cluster.local/h11912099
# (psycopg2.errors.SyntaxError) syntax error at or near ".."
# LINE 1: ...
#         ^
#
# [SQL: ...]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## Task 3.2
#
# Names of architects that have designed buildings buildings built after 1st of October 2013:

# %%
# %%sql
#
# ...
# Out:
#  * postgresql://h11912099:***@postgresql.student-db.svc.cluster.local/h11912099
# (psycopg2.errors.SyntaxError) syntax error at or near ".."
# LINE 1: ...
#         ^
#
# [SQL: ...]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## Task 3.3
#
# The architect's ID (pID), name, and count of how many buildings the architect has designed per person.
# *(HINT: only needs to cover persons that have acrtually been architects of some building... we will learn more complex SQL in the Data Management and analytics course to also cover those persons that have not designed any buildings in such a query)*

# %%
# %%sql
#
# ...
# Out:
#  * postgresql://h11912099:***@postgresql.student-db.svc.cluster.local/h11912099
# (psycopg2.errors.SyntaxError) syntax error at or near ".."
# LINE 1: ...
#         ^
#
# [SQL: ...]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## Task 3.4
#
# The pIDs and names of the top 3 architects in terms of the number of buildings they designed.
# *(HINT: In case of ties, prefer the architect with the lower pid, but return only three results.)*

# %%
# %%sql
#
# ...
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/IPython/core/async_helpers.py:129, in _pseudo_sync_runner(coro)
#     121 """
#     122 A runner that does not really allow async execution, and just advance the coroutine.
#     123
#    (...)
#     126 Credit to Nathaniel Smith
#     127 """
#     128 try:
# --> 129     coro.send(None)
#     130 except StopIteration as exc:
#     131     return exc.value
#
# File /opt/conda/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3088, in InteractiveShell.run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple, cell_id)
#    3086 # Store raw and processed history
#    3087 if store_history and raw_cell.strip(" %") != "paste":
# -> 3088     self.history_manager.store_inputs(self.execution_count, cell, raw_cell)
# ...

# %% [markdown]
# # Task 4
#
# Given the following queries expressed as Relational Algebra... provide the corresponding SQL.
# *(Hint: admittedly not all of these queries make sense ;-))*

# %% [markdown]
# ## Task 4.1
#
# $\pi_{pID}(\sigma_{date\_of\_birth < '1960-01-01'}(Person))$

# %%
# %%sql
#
# ...

# %% [markdown]
# ## Task 4.2
#
# $\pi_{inception\_date, date\_of\_birth}(building \bowtie_{building.bid=architect.bid} (architect \bowtie_{{architect.pid=person.pid}} person ))$

# %%
# %%sql
#
# ...

# %% [markdown]
# ## Task 4.3
#
# $\sigma_{building.name = person.name }(building \times person)$

# %%
# %%sql
#
# ...

# %% [markdown]
# # Task 5
#
# Now we will practice the other way around... Draw/Write down the Relation Algebra expression for the following queries expressed in SQL:

# %% [markdown]
# ## Task 5.1

# %%
# %%sql
#
# SELECT date_of_birth FROM person WHERE name = 'Zaha Hadid';

# %% [markdown]
# -- ADD YOUR RELATIONAL ALGEBRA EXPRESSION HERE ... *(HINT: you can use markdown for [LaTeX equations notation](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html) or just upload an image of a hand-written relational algebra expression...)*

# %% [markdown]
# ## Task 5.2

# %%
# %%sql
#
# SELECT person.name, bid FROM person JOIN architect ON architect.pid = person.pid;

# %% [markdown]
# -- ADD YOUR RELATIONAL ALGEBRA EXPRESSION HERE ... *(HINT: you can use markdown for [LaTeX equations notation](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html) or just upload an image of a hand-written relational algebra expression...)*

# %% [markdown]
# # Task 6
#
# When you look up the respective other buildings at WU (e.g. on Wikipedia or on http://wikidata.org), you will realize that several of the buildings at WU have not been designed by single architects, but by architect firms.
#
# How would you need to modify the ER diagram and the CREATE TABLE statements from Task 1 on order to reflect that
# * buildings are designed by architect firms rather than persons;
# * architect firms have an id (primary key), a name and a founding date;
# * each architect firm has one or more founders (persons);
# * each person can be the founder of ar most one architect firm.

# %% [markdown]
# ## Task 6.1
#
# --- DRAW YOUR MODIFIED ER DIAGRAM HERE

# %% [markdown]
# ## Task 6.2

# %% [markdown]
# Freestyle & further practice: keep on practicing, by
#  - modifying/adapting the CREATE TABLE statements from Task 1 reflecting the changes in the ER diagram
#  - add data to reflect all the buildings at WU, the architect firms that designed them and (where you can find them, the founders of these firms.
#  - think of more queries in SQL and try them out

# %%
# %%sql
#
# ...
